# %%
# %load_ext lab_black

# Common Imports
import numpy as np
import pandas as pd

# Preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.impute import SimpleImputer

# Assessing performance
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV, RepeatedStratifiedKFold

# Classifiers
from sklearn.neighbors import KNeighborsClassifier

# Regressors
from sklearn.linear_model import LinearRegression

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rc("axes", labelsize=14)
mpl.rc("xtick", labelsize=12)
mpl.rc("ytick", labelsize=12)

# Ignore useless warnings (see SciPy issue #5998)
import warnings

warnings.filterwarnings(action="ignore", message="^internal gelsd")
warnings.filterwarnings("ignore")
warnings.filterwarnings(action="ignore", category=DeprecationWarning)
warnings.filterwarnings(action="ignore", category=FutureWarning)

# To make this notebook's output identical at every run
np.random.seed(42)

# %%
data = (
    pd.read_csv("position_logs.csv")
    .query("marker % 2 == 0 and marker < 6")
    .reset_index(drop=True)
)

data.marker = data.marker.map({j: i + 1 for i, j in enumerate(data.marker.unique())})

data.columns = [
    "position",
    "tag",
    "anchor_1",
    "anchor_2",
    "anchor_3",
    "anchor_4",
    "anchor_5",
]

data
# Out:
#       position  tag  anchor_1  anchor_2  anchor_3  anchor_4  anchor_5
# 0            1    1       940     185.0     453.0     515.0     560.0
# 1            1    2       855     185.0     505.0     484.0     581.0
# 2            1    3       939     191.0     483.0     527.0     587.0
# 3            1    1       939     186.0     454.0     510.0     555.0
# 4            1    2       852     186.0     503.0     487.0     583.0
# ...        ...  ...       ...       ...       ...       ...       ...
# 6136         3    2       861     526.0     383.0     629.0     190.0
# 6137         3    3       843     581.0     392.0     688.0     212.0
# 6138         3    1       802     600.0     404.0     636.0     183.0
# 6139         3    2       832     526.0     377.0     625.0     189.0
# 6140         3    3       840     579.0     392.0     688.0     201.0
#
# [6141 rows x 7 columns]

# %%
position = data.query("tag == 1").loc[:, ["position"]].reset_index(drop=True)

data_tag_1 = (
    data.query("tag == 1").drop(["position", "tag"], axis=1).reset_index(drop=True)
)

data_tag_2 = (
    data.query("tag == 2").drop(["position", "tag"], axis=1).reset_index(drop=True)
)

data_tag_3 = (
    data.query("tag == 3").drop(["position", "tag"], axis=1).reset_index(drop=True)
)

# %%
data_tag_1.columns = map("{}_tag_1".format, data_tag_1.columns)
data_tag_2.columns = map("{}_tag_2".format, data_tag_2.columns)
data_tag_3.columns = map("{}_tag_3".format, data_tag_3.columns)

# %%
data = position.join([data_tag_1, data_tag_2, data_tag_3])
data
# Out:
#       position  anchor_1_tag_1  anchor_2_tag_1  anchor_3_tag_1  \
# 0            1             940           185.0           453.0
# 1            1             939           186.0           454.0
# 2            1             939           188.0           458.0
# 3            1             942           186.0           457.0
# 4            1             940           185.0           457.0
# ...        ...             ...             ...             ...
# 2042         3             806           596.0           403.0
# 2043         3             804           598.0           402.0
# 2044         3             800           596.0           405.0
# 2045         3             810           596.0           405.0
# 2046         3             802           600.0           404.0
#
#       anchor_4_tag_1  anchor_5_tag_1  anchor_1_tag_2  anchor_2_tag_2  \
# 0              515.0           560.0             855           185.0
# 1              510.0           555.0             852           186.0
# 2              509.0           568.0             854           183.0
# 3              509.0           561.0             852           181.0
# 4              510.0           550.0             852           185.0
# ...              ...             ...             ...             ...
# 2042           635.0           181.0             816           528.0
# 2043           636.0           183.0             846           530.0
# 2044           636.0           184.0             861           529.0
# 2045           636.0           186.0             861           526.0
# 2046           636.0           183.0             832           526.0
#
#       anchor_3_tag_2  anchor_4_tag_2  anchor_5_tag_2  anchor_1_tag_3  \
# 0              505.0           484.0           581.0             939
# 1              503.0           487.0           583.0             935
# 2              500.0           483.0           580.0             936
# 3              503.0           484.0           583.0             936
# 4              502.0           484.0           582.0             941
# ...              ...             ...             ...             ...
# 2042           386.0           628.0           190.0             842
# 2043           378.0           629.0           188.0             837
# 2044           376.0           627.0           190.0             840
# 2045           383.0           629.0           190.0             843
# 2046           377.0           625.0           189.0             840
#
#       anchor_2_tag_3  anchor_3_tag_3  anchor_4_tag_3  anchor_5_tag_3
# 0              191.0           483.0           527.0           587.0
# 1              190.0           484.0           527.0           585.0
# 2              193.0           484.0           525.0           588.0
# 3              192.0           484.0           527.0           586.0
# 4              192.0           484.0           528.0           586.0
# ...              ...             ...             ...             ...
# 2042           579.0           396.0           689.0           216.0
# 2043           581.0           394.0           686.0           215.0
# 2044           584.0           394.0           688.0           208.0
# 2045           581.0           392.0           688.0           212.0
# 2046           579.0           392.0           688.0           201.0
#
# [2047 rows x 16 columns]

# %%
pos_uniq = data["position"].unique()
pos_coord = [(1597, 1958), (766, 1690), (530, 2040)]

pos_to_coord = dict(zip(pos_uniq, pos_coord))

for pos in pos_to_coord.keys():
    x, y = pos_to_coord[pos]
    data.loc[data["position"] == pos, "x"] = x
    data.loc[data["position"] == pos, "y"] = y

data
# Out:
#       position  anchor_1_tag_1  anchor_2_tag_1  anchor_3_tag_1  \
# 0            1             940           185.0           453.0
# 1            1             939           186.0           454.0
# 2            1             939           188.0           458.0
# 3            1             942           186.0           457.0
# 4            1             940           185.0           457.0
# ...        ...             ...             ...             ...
# 2042         3             806           596.0           403.0
# 2043         3             804           598.0           402.0
# 2044         3             800           596.0           405.0
# 2045         3             810           596.0           405.0
# 2046         3             802           600.0           404.0
#
#       anchor_4_tag_1  anchor_5_tag_1  anchor_1_tag_2  anchor_2_tag_2  \
# 0              515.0           560.0             855           185.0
# 1              510.0           555.0             852           186.0
# 2              509.0           568.0             854           183.0
# 3              509.0           561.0             852           181.0
# 4              510.0           550.0             852           185.0
# ...              ...             ...             ...             ...
# 2042           635.0           181.0             816           528.0
# 2043           636.0           183.0             846           530.0
# 2044           636.0           184.0             861           529.0
# 2045           636.0           186.0             861           526.0
# 2046           636.0           183.0             832           526.0
#
#       anchor_3_tag_2  anchor_4_tag_2  anchor_5_tag_2  anchor_1_tag_3  \
# 0              505.0           484.0           581.0             939
# 1              503.0           487.0           583.0             935
# 2              500.0           483.0           580.0             936
# 3              503.0           484.0           583.0             936
# 4              502.0           484.0           582.0             941
# ...              ...             ...             ...             ...
# 2042           386.0           628.0           190.0             842
# 2043           378.0           629.0           188.0             837
# 2044           376.0           627.0           190.0             840
# 2045           383.0           629.0           190.0             843
# 2046           377.0           625.0           189.0             840
#
#       anchor_2_tag_3  anchor_3_tag_3  anchor_4_tag_3  anchor_5_tag_3       x  \
# 0              191.0           483.0           527.0           587.0  1597.0
# 1              190.0           484.0           527.0           585.0  1597.0
# 2              193.0           484.0           525.0           588.0  1597.0
# 3              192.0           484.0           527.0           586.0  1597.0
# 4              192.0           484.0           528.0           586.0  1597.0
# ...              ...             ...             ...             ...     ...
# 2042           579.0           396.0           689.0           216.0   530.0
# 2043           581.0           394.0           686.0           215.0   530.0
# 2044           584.0           394.0           688.0           208.0   530.0
# 2045           581.0           392.0           688.0           212.0   530.0
# 2046           579.0           392.0           688.0           201.0   530.0
#
#            y
# 0     1958.0
# 1     1958.0
# 2     1958.0
# 3     1958.0
# 4     1958.0
# ...      ...
# 2042  2040.0
# 2043  2040.0
# 2044  2040.0
# 2045  2040.0
# 2046  2040.0
#
# [2047 rows x 18 columns]

# %%
# Amount of readings per location
data["position"].value_counts()
# Out:
# 2    793
# 1    684
# 3    570
# Name: position, dtype: int64

# %%
data.hist(bins=5, figsize=(15, 15))
plt.show()

# %%
X_train = data.drop(["position", "x", "y"], axis=1)

# %%
# Normalization
min_max_scaler = MinMaxScaler()
min_max_scaled_features = min_max_scaler.fit_transform(X_train)

# %%
X_train = pd.DataFrame(
    min_max_scaled_features, index=X_train.index, columns=X_train.columns
)
X_train = position.join(X_train)
X_train
# Out:
#       position  anchor_1_tag_1  anchor_2_tag_1  anchor_3_tag_1  \
# 0            1        0.990814        0.007886        0.427900
# 1            1        0.989501        0.009464        0.429467
# 2            1        0.989501        0.012618        0.435737
# 3            1        0.993438        0.009464        0.434169
# 4            1        0.990814        0.007886        0.434169
# ...        ...             ...             ...             ...
# 2042         3        0.814961        0.656151        0.349530
# 2043         3        0.812336        0.659306        0.347962
# 2044         3        0.807087        0.656151        0.352665
# 2045         3        0.820210        0.656151        0.352665
# 2046         3        0.809711        0.662461        0.351097
#
#       anchor_4_tag_1  anchor_5_tag_1  anchor_1_tag_2  anchor_2_tag_2  \
# 0           0.722944        0.974555        0.833124        0.011382
# 1           0.712121        0.961832        0.829360        0.013008
# 2           0.709957        0.994911        0.831870        0.008130
# 3           0.709957        0.977099        0.829360        0.004878
# 4           0.712121        0.949109        0.829360        0.011382
# ...              ...             ...             ...             ...
# 2042        0.982684        0.010178        0.784191        0.569106
# 2043        0.984848        0.015267        0.821832        0.572358
# 2044        0.984848        0.017812        0.840652        0.570732
# 2045        0.984848        0.022901        0.840652        0.565854
# 2046        0.984848        0.015267        0.804266        0.565854
#
#       anchor_3_tag_2  anchor_4_tag_2  anchor_5_tag_2  anchor_1_tag_3  \
# 0           0.520661        0.672566        0.982885        0.986541
# 1           0.517355        0.679204        0.987775        0.981157
# 2           0.512397        0.670354        0.980440        0.982503
# 3           0.517355        0.672566        0.987775        0.982503
# 4           0.515702        0.672566        0.985330        0.989233
# ...              ...             ...             ...             ...
# 2042        0.323967        0.991150        0.026895        0.855989
# 2043        0.310744        0.993363        0.022005        0.849260
# 2044        0.307438        0.988938        0.026895        0.853297
# 2045        0.319008        0.993363        0.026895        0.857335
# 2046        0.309091        0.984513        0.024450        0.853297
#
#       anchor_2_tag_3  anchor_3_tag_3  anchor_4_tag_3  anchor_5_tag_3
# 0           0.009804        0.391053        0.660532          0.9650
# 1           0.008403        0.392496        0.660532          0.9600
# 2           0.012605        0.392496        0.656442          0.9675
# 3           0.011204        0.392496        0.660532          0.9625
# 4           0.011204        0.392496        0.662577          0.9625
# ...              ...             ...             ...             ...
# 2042        0.553221        0.265512        0.991820          0.0375
# 2043        0.556022        0.262626        0.985685          0.0350
# 2044        0.560224        0.262626        0.989775          0.0175
# 2045        0.556022        0.259740        0.989775          0.0275
# 2046        0.553221        0.259740        0.989775          0.0000
#
# [2047 rows x 16 columns]

# %%
X_train.loc[X_train["position"] == 1] = (
    X_train.query("position == 1")
    .drop(["position"], axis=1)
    .reset_index(drop=True)
    .fillna(X_train.query("position == 1").mean())
)
# X_train.query()

# %%
X_train.query("position != 2 and position != 3").drop("position", axis=1).isnull().any(axis=1).sum()
# Out:
# 0

# %%
data_pos_1.anchor_5_tag_1.mean()
# Out:
# 0.9486112381828748

# %%
# all the rows in the 2nd position have at least null value (anchor 5)
X_train.query("position == 2").isnull().any(axis=1)
# Out:
# 684     True
# 685     True
# 686     True
# 687     True
# 688     True
#         ...
# 1472    True
# 1473    True
# 1474    True
# 1475    True
# 1476    True
# Length: 793, dtype: bool

# %%
# Get all rows with one or more null values
X_train[X_train.isnull().any(axis=1)]
# Out:
#       anchor_1_tag_1  anchor_2_tag_1  anchor_3_tag_1  anchor_4_tag_1  \
# 31          0.989501        0.432177        0.515674        0.829004
# 73          0.992126        0.009464        0.429467        0.707792
# 82          0.993438        0.432177        0.510972        0.813853
# 89          0.993438        0.430599        0.518809        0.809524
# 117         0.000000        0.430599        0.514107        0.805195
# ...              ...             ...             ...             ...
# 1963        0.817585        0.356467        0.714734        0.002165
# 1970        0.805774        0.356467        0.719436        0.002165
# 1986        0.805774        0.656151        0.354232        0.978355
# 2011        0.813648        0.656151        0.349530        0.987013
# 2014        0.812336        0.720820        0.000000             NaN
#
#       anchor_5_tag_1  anchor_1_tag_2  anchor_2_tag_2  anchor_3_tag_2  \
# 31               NaN        0.828105        0.530081        0.487603
# 73          0.946565        0.830615        0.009756        0.523967
# 82               NaN        0.830615        0.528455        0.492562
# 89               NaN        0.830615        0.530081        0.494215
# 117              NaN        0.836888        0.009756        0.519008
# ...              ...             ...             ...             ...
# 1963             NaN        0.819322        0.330081        0.720661
# 1970             NaN        0.797992        0.328455        0.723967
# 1986        0.012723        0.898369        0.569106        0.719008
# 2011        0.027990        0.836888        0.569106        0.315702
# 2014             NaN        0.782936        0.725203        0.000000
#
#       anchor_4_tag_2  anchor_5_tag_2  anchor_1_tag_3  anchor_2_tag_3  \
# 31          0.880531             NaN        0.981157        0.414566
# 73          0.676991             NaN        0.982503        0.014006
# 82          0.876106             NaN        0.981157        0.418768
# 89          0.884956             NaN        0.978466        0.418768
# 117         0.681416        0.987775        0.979812        0.012605
# ...              ...             ...             ...             ...
# 1963        0.013274             NaN        0.855989        0.292717
# 1970        0.000000             NaN        0.855989        0.296919
# 1986        0.022124             NaN        0.860027        0.558824
# 2011        0.988938        0.026895        0.864065        0.292717
# 2014             NaN             NaN        0.861373        0.707283
#
#       anchor_3_tag_3  anchor_4_tag_3  anchor_5_tag_3
# 31          0.457431        0.787321             NaN
# 73          0.392496        0.662577          0.9925
# 82          0.457431        0.783231             NaN
# 89          0.450216        0.779141             NaN
# 117         0.391053        0.662577          0.9575
# ...              ...             ...             ...
# 1963        0.686869        0.014315             NaN
# 1970        0.689755        0.014315             NaN
# 1986        0.258297        0.983640          0.0300
# 2011        0.686869             NaN             NaN
# 2014        0.000000             NaN             NaN
#
# [845 rows x 15 columns]

# %%
# Fill all null values after normalization or else it may impact the distribution

# if the poistion of the rows with the null values is the same

# %%
X_train = pd.DataFrame(min_max_scaled_features, index=X_train.index, columns=X_train.columns)

X_train = X_train.apply(lambda row: row.fillna(row.mean()), axis=1)

X_train

# %%
y_train = data["position"].copy()
y_train

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2).fit(X_train)
pca_2d = pca.transform(X_train)

import pylab as pl
for i in range(0, pca_2d.shape[0]):
    if y_train[i] == 1:
        c1 = pl.scatter(pca_2d[i,0],pca_2d[i,1],c='r',marker='+')
    elif y_train[i] == 2:
        c2 = pl.scatter(pca_2d[i,0],pca_2d[i,1],c='g',marker='o')
    elif y_train[i] == 3:
        c3 = pl.scatter(pca_2d[i,0],pca_2d[i,1],c='b',marker='*')

pl.legend([c1, c2, c3], ['Position 1', 'Position 2', 'Position 3'])
pl.title('Dataset with 3 clusters and known outcomes')
pl.show()

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)

# %%
n_neighbors = range(1, 21, 2)
weights = ['uniform', 'distance']
metric = ['euclidean', 'manhattan', 'minkowski']

grid = dict(n_neighbors=n_neighbors, weights=weights, metric=metric)

grid_search = GridSearchCV(KNeighborsClassifier(), param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy')
grid_search.fit(X_train, y_train)

print("Parameters: %s with an accuracy of %f" % (grid_search.best_params_, grid_search.best_score_))

# %%
knn_clf = grid_search.best_estimator_
